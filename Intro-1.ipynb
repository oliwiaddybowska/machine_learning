# %%
# Introduction to Python
# Jai Woo Lee, 2022-09-20

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
# variable
x = 28
y = x
y = 3456

print(y)
# Out:
# 3456

# %%
print(x)
# Out:
# 28

# %%
# +
# - 
# /
# //
# %
# *
# **

# %%
#  <
#  >
#  <=
#  >=
#  ==
#  != 

#  not
#  and
#  or

# %%
2 * 3
# Out:
# 6

# %%
3 ** 2
# Out:
# 9

# %%
7 / 3.0
# Out:
# 2.3333333333333335

# %%
7 % 3 # rest from division
# Out:
# 1

# %%
7 // 3.0 # largest int from division
# Out:
# 2.0

# %%
4 + 3 * 9
# Out:
# 31

# %%
(4 + 3) * 9
# Out:
# 63

# %%
9 * (4 + 3)
# Out:
# 63

# %%
seoul_pop = 9976000
sejong_pop = 355831

seoul_pop < sejong_pop
# Out:
# False

# %%
4 == 3
# Out:
# False

# %%
4 != 3
# Out:
# True

# %%
print(type(sejong_pop))
print(type(100000 < sejong_pop))
print(type("Sejong"))
# Out:
# <class 'int'>
# <class 'bool'>
# <class 'str'>

# %%
print(28 + 3456)
# Out:
# 3484

# %%
string_num = "3456"
num = 28

num + string_num
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 4>()
#       1 string_num = "3456"
#       2 num = 28
# ----> 4 num + string_num
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print ("100" + "001")
print(str(100)+str(368))
# Out:
# 100001
# 100368

# %%
string_num = "3456"
num = 28

float(string_num) + num
# Out:
# 3484.0

# %%
print "There was only one catch and that was Catch-" + 28
# Out:
#   File "<ipython-input-13-a4aa7eb79389>", line 1
#     print "There was only one catch and that was Catch-" + 28
#                                                        ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("There was only one catch and that was Catch-" + 28)?

# %%
print ("Choose a value, {0}.".format(28))
# Out:
# Choose a value, 28.

# %%
# String Formatting
print ("From {0} to {1}, in {1} seconds.".format(0, 60))
# Out:
# From 0 to 60, in 60 seconds.

# %%
# Logic
x = 3
y = 4
z = 2
a = 1

print (x < y and z == 2)
print (y < x or a < z)
print (not y < x)
# Out:
# True
# True
# True
