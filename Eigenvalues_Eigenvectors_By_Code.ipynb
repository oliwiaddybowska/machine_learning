# %%
import numpy as np
from numpy.linalg import eig

# %%
a = np.array([[3, 2], 
              [-1, 6]])
w,v=eig(a)
print('E-value:', w)
print('E-vector', v)
# Out:
# E-value: [4. 5.]
# E-vector [[-0.89442719 -0.70710678]
#  [-0.4472136  -0.70710678]]
